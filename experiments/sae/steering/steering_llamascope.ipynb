# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from sae_lens import HookedSAETransformer, SAE
from collections import defaultdict
import pandas as pd
from functools import partial
import json
import transformer_lens.utils as utils

# %% [markdown]
# ## Setup

# %%
MODEL_NAME   = "meta-llama/Llama-3.1-8B"
HF_TOKEN     = "..."
FEATURES_CSV = "./latent_outputs/chosen_features.csv"
DEV_PROMPTS  = "./prompts_dataset_dev.json"
TEST_PROMPTS = "./prompts_dataset_test.json"
# LAYERS       = [15, 16]
LAYERS       = [15, 16]
ALPHAS       = [0.1, 0.5, 1.0, 1.5, 2.0]
DEVICE       = 'cuda' if torch.cuda.is_available() else 'cpu'

# Seed
torch.manual_seed(0)
torch.set_grad_enabled(False)

# %% [markdown]
# Load Model & Tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, token=HF_TOKEN)
model = HookedSAETransformer.from_pretrained(
    MODEL_NAME, 
    device_map="auto", 
    use_auth_token=HF_TOKEN
).to(DEVICE)
model.eval()
# Out:
# /auto/brno2/home/ariuka/tense/venv/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:root:You are not using LayerNorm, so the writing weights can't be centered! Skipping
# Loaded pretrained model meta-llama/Llama-3.1-8B into HookedTransformer
# Moving model to device:  cuda
# HookedSAETransformer(
#   (embed): Embed()
#   (hook_embed): HookPoint()
#   (blocks): ModuleList(
#     (0-31): 32 x TransformerBlock(
#       (ln1): RMSNormPre(
#         (hook_scale): HookPoint()
#         (hook_normalized): HookPoint()
#       )
#       (ln2): RMSNormPre(
#         (hook_scale): HookPoint()
#         (hook_normalized): HookPoint()
#       )
#       (attn): GroupedQueryAttention(
#         (hook_k): HookPoint()
#         (hook_q): HookPoint()
#         (hook_v): HookPoint()
#         (hook_z): HookPoint()
#         (hook_attn_scores): HookPoint()
#         (hook_pattern): HookPoint()
#         (hook_result): HookPoint()
#         (hook_rot_k): HookPoint()
#         (hook_rot_q): HookPoint()
#       )
#       (mlp): GatedMLP(
#         (hook_pre): HookPoint()
#         (hook_pre_linear): HookPoint()
#         (hook_post): HookPoint()
#       )
#       (hook_attn_in): HookPoint()
#       (hook_q_input): HookPoint()
#       (hook_k_input): HookPoint()
#       (hook_v_input): HookPoint()
#       (hook_mlp_in): HookPoint()
#       (hook_attn_out): HookPoint()
#       (hook_mlp_out): HookPoint()
#       (hook_resid_pre): HookPoint()
#       (hook_resid_mid): HookPoint()
#       (hook_resid_post): HookPoint()
#     )
#   )
#   (ln_final): RMSNormPre(
#     (hook_scale): HookPoint()
#     (hook_normalized): HookPoint()
#   )
#   (unembed): Unembed()
# )

# %%
if tokenizer.pad_token is None:
    # reuse eos_token as pad
    tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# Load SAEs for each layer and collect feature indices

# %%
# Read CSV of chosen features (with columns: label, layer, feature)
df_feats = pd.read_csv(FEATURES_CSV)
dims_map = defaultdict(lambda: defaultdict(list))
for _, row in df_feats.iterrows():
    dims_map[row['label']][int(row['layer'])].append(int(row['feature']))
    
dims_map
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'past': defaultdict(list,
#                          {15: [18461, 2056, 18461, 17012, 20700, 2056],
#                           16: [3146, 2546, 3146, 2546],
#                           17: [3247, 8103, 3247, 18353, 8103]}),
#              'present': defaultdict(list,
#                          {15: [18003, 18003, 25167],
#                           16: [20666, 27221, 20666],
#                           17: [17274,
#                            26778,
#                            24848,
#                            11683,
#                            17274,
#                            23345,
#                            26778]}),
#              'future': defaultdict(list,
#                          {15: [32069, 32069, 23445],
#                           16: [7255, 7255, 8351, 10758],
#                           17: [22423, 22423, 18865, 10144]})})

# %%
# Pre-load SAE modules
saes = {}
for layer in LAYERS:
    hook_name = f"l{layer}r_8x"
    sae_module, _, _ = SAE.from_pretrained(
        release="llama_scope_lxr_8x",
        sae_id=hook_name,
        device=DEVICE
    )
    sae_module.eval()
#     saes[hook_name] = sae_module
    saes[sae_module.cfg.hook_name] = sae_module

print(saes.keys())
# Out:
# dict_keys(['blocks.15.hook_resid_post', 'blocks.16.hook_resid_post'])

# %% [markdown]
# ### Helper functions

# %%
def evaluate_baseline(prompts):
    counts   = defaultdict(int)
    corrects = defaultdict(int)
    
    for ex in prompts:
        prompt = ex["prompt_text"]
        gold   = ex["gold_answer"]
        label  = ex["gold_tense"]

        # 1. Tokenize single sequence, no padding
        toks = tokenizer(prompt, return_tensors="pt").to(DEVICE)

        # 2. Run once to get logits
        logits, _ = model.run_with_cache(toks.input_ids)

        # 3. Grab the last‐token logits
        last_logits = logits[0, -1, :]          # shape (vocab_size,)

        # 4. Greedy pick
        next_id = last_logits.argmax(dim=-1)  # scalar

        # 5. Decode only that new token
        pred = tokenizer.decode(next_id.unsqueeze(0), skip_special_tokens=True).strip()

        # 6. Print + accumulate
        print(f"Prompt: {prompt!r} → Pred: {pred!r} | Gold: {gold!r}")
        
        counts[label] += 1
        if pred and pred[0] == gold:
            corrects[label] += 1

    # compute accuracy per label
    accuracies = {
        lbl: corrects[lbl] / counts[lbl]
        for lbl in counts
    }
    return accuracies

# --- Custom Ablation Function ---
def ablate_sae_feature(h, pos: int or None, feature_ids: list):
    # h: [B, T, latent_dim]
    if pos is None:
        h[:, :, feature_ids] = 0.0
    else:
        h[:, pos, feature_ids] = 0.0
    return h

# --- Evaluate with run_with_saes (scaling or ablation) ---
def evaluate_with_saes(prompts, alpha):
    counts   = defaultdict(int)
    corrects = defaultdict(int)

    for ex in prompts:
        prompt = ex["prompt_text"]
        gold   = ex["gold_answer"]
        label  = ex["gold_tense"]

        # load one SAE module per layer, scaled by alpha
        scaled_saes = []
        for layer in LAYERS:
            hook_name = utils.get_act_name("resid_post", layer)  # e.g., "blocks.15.hook_resid_post"
            feature_idxs = dims_map[label][layer]
#             print(f'label = {label}, layer = {layer}')
#             print(feature_idxs)
            base_sae     = saes[hook_name]

            class ScaledSAE(torch.nn.Module):
                def __init__(self, sae, idxs, alpha, hook_name):
                    super().__init__()
                    self.sae   = sae
                    self.idxs  = idxs
                    self.alpha = alpha
                    self.cfg   = sae.cfg
                    self.cfg.hook_name = hook_name

                def forward(self, z):
                    h = self.sae.encode(z)
                    h[:, :, self.idxs] *= self.alpha
                    return self.sae.decode(h)
            
            mod = ScaledSAE(base_sae, feature_idxs, alpha, hook_name)
            scaled_saes.append(mod)

        # tokenize single prompt
        toks = tokenizer(prompt, return_tensors="pt").to(DEVICE)

        # run with SAEs
        logits = model.run_with_saes(
            toks.input_ids,
            saes=scaled_saes,
            use_error_term=None
        )

        # greedy next‐token
        next_id = logits[0, -1, :].argmax(dim=-1)
        pred    = tokenizer.decode(next_id.unsqueeze(0), skip_special_tokens=True).strip()

        print(f"Prompt: {prompt!r} → Pred: {pred!r} | Gold: {gold!r}")

        counts[label] += 1
        if pred and pred[0] == gold:
            corrects[label] += 1

    # compute accuracy per label
    accuracies = {
        lbl: corrects[lbl] / counts[lbl]
        for lbl in counts
    }
    return accuracies

# %% [markdown]
# ## Demo test before Grid search

# %%
# # Prepare first 5 sentences from dev per label for demo
# with open(DEV_PROMPTS) as f:
#     dev_data = json.load(f)

# pilot = []
# counts = {
#     'past': 0,
#     'present': 0,
#     'future': 0,
# }
# for ex in dev_data:
#     if counts[ex['gold_tense']] < 5:
#         pilot.append(ex)
#         counts[ex['gold_tense']] += 1
#     if all(c >= 5 for c in counts.values()):
#         break

# %%
# Baseline
accuracy = evaluate_baseline(dev_data)
print(accuracy)
# Out:
# Prompt: 'Last night, I ___ the journal.\nA) drew\nB) will draw\nC) draw\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Earlier today, she ___ the lecture.\nA) will explore\nB) explored\nC) explores\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Yesterday, I ___ the ball.\nA) watched\nB) will watch\nC) watch\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Last summer, the dog ___ the exam.\nA) summarizes\nB) summarized\nC) will summarize\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'A week ago, the musician ___ the cake.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Back then, the students ___ the cake.\nA) will speak\nB) spoke\nC) speaks\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last night, he ___ the game.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Once upon a time, the birds ___ a letter.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Back then, he ___ the phone.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Once upon a time, the dog ___ the exam.\nA) meowed\nB) will meow\nC) meows\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'In my childhood, he ___ the book.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Last Monday, the driver ___ the presentation.\nA) eats\nB) will eat\nC) ate\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'A week ago, the cooks ___ the cake.\nA) summarized\nB) will summarize\nC) summarizes\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Last summer, the cat ___ the movie.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Last summer, the cat ___ the lecture.\nA) baked\nB) will bake\nC) bakes\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Yesterday, the students ___ the game.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Once upon a time, the athletes ___ the meeting.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Back then, the driver ___ the house.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'A week ago, the robot ___ the phone.\nA) sings\nB) sung\nC) will sing\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Once upon a time, the engineer ___ the presentation.\nA) will listen\nB) listened\nC) listens\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last night, you ___ the homework.\nA) spoke\nB) speak\nC) will speak\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Back then, the parents ___ the ball.\nA) sleeps\nB) will sleep\nC) slept\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Last summer, the birds ___ the phone.\nA) smiled\nB) smiles\nC) will smile\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Last summer, the birds ___ the painting.\nA) will summarize\nB) summarizes\nC) summarized\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'In my childhood, the artists ___ the movie.\nA) will teach\nB) taught\nC) teaches\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last summer, they ___ the computer.\nA) walk\nB) walked\nC) will walk\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last summer, the parents ___ the problem.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Last summer, the team ___ the mailman.\nA) likes\nB) will like\nC) liked\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Yesterday, she ___ the presentation.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'A week ago, the child ___ the ball.\nA) chirps\nB) chirped\nC) will chirp\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the robot ___ the painting.\nA) will write\nB) wrote\nC) writes\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Every Monday, they ___ the cake.\nA) design\nB) designed\nC) will design\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Usually, the robot ___ the painting.\nA) plays\nB) played\nC) will play\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Every Saturday, the cooks ___ the project.\nA) jumps\nB) will jump\nC) jumped\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Always, the cat ___ the book.\nA) will meow\nB) meows\nC) meowed\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Every morning, the robot ___ the book.\nA) carried\nB) will carry\nC) carries\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Always, the athletes ___ the project.\nA) barked\nB) will bark\nC) barks\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Everyday, the students ___ the ball.\nA) will deliver\nB) delivered\nC) delivers\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'In this instant, the dog ___ the phone.\nA) writes\nB) wrote\nC) will write\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Usually, the company ___ the car.\nA) played\nB) will play\nC) plays\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Every Saturday, the doctors ___ the car.\nA) will dream\nB) dreams\nC) dreamt\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, you ___ the game.\nA) drove\nB) will drive\nC) drive\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Usually, the dog ___ the phone.\nA) will solve\nB) solved\nC) solves\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Often, the birds ___ the house.\nA) will dance\nB) danced\nC) dances\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Monday, she ___ a letter.\nA) summarized\nB) summarizes\nC) will summarize\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the cat ___ the movie.\nA) dreams\nB) will dream\nC) dreamt\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Usually, the engineer ___ a letter.\nA) will eat\nB) eats\nC) ate\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Every Saturday, the birds ___ the house.\nA) paints\nB) will paint\nC) painted\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Often, the dog ___ the test.\nA) watched\nB) will watch\nC) watches\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Sometimes, you ___ a letter.\nA) will carry\nB) carry\nC) carried\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Everyday, the team ___ the ball.\nA) drank\nB) will drink\nC) drinks\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Usually, the engineer ___ the homework.\nA) saw\nB) will see\nC) sees\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Every morning, he ___ the car.\nA) constructs\nB) constructed\nC) will construct\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Every week, the dog ___ the lecture.\nA) will bake\nB) baked\nC) bakes\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Every Saturday, we ___ the lecture.\nA) summarize\nB) will summarize\nC) summarized\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Sometimes, he ___ the mailman.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the robot ___ the problem.\nA) will deliver\nB) delivers\nC) delivered\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Sometimes, he ___ the book.\nA) will jump\nB) jumps\nC) jumped\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'In this instant, the robot ___ the exam.\nA) cooked\nB) cooks\nC) will cook\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Every Monday, the teacher ___ the lecture.\nA) will walk\nB) walked\nC) walks\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Next week, she ___ the journal.\nA) will discover\nB) discovered\nC) discovers\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, the parents ___ the problem.\nA) will drive\nB) drove\nC) drives\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Before long, the company ___ the cake.\nA) will bark\nB) barked\nC) barks\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'By next year, you ___ the mailman.\nA) will drive\nB) drove\nC) drive\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Soon, the musician ___ the phone.\nA) built\nB) builds\nC) will build\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Next week, he ___ the exam.\nA) spoke\nB) speaks\nC) will speak\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Later today, the child ___ the phone.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Tomorrow, the teacher ___ the presentation.\nA) will cry\nB) cries\nC) cried\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'In the near future, the cooks ___ the homework.\nA) flies\nB) flew\nC) will fly\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Next year, we ___ the book.\nA) will eat\nB) ate\nC) eat\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Tomorrow, they ___ the journal.\nA) will drive\nB) drive\nC) drove\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, they ___ the exam.\nA) will walk\nB) walk\nC) walked\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Shortly, the cat ___ the problem.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'In the near future, the cat ___ the mailman.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Later today, the birds ___ the ball.\nA) draws\nB) will draw\nC) drew\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Before long, the students ___ the mailman.\nA) will jog\nB) jogs\nC) jogged\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Next year, the birds ___ a letter.\nA) walks\nB) walked\nC) will walk\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Later today, the students ___ the car.\nA) liked\nB) likes\nC) will like\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'In a few days, the child ___ the problem.\nA) will sing\nB) sung\nC) sings\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Tomorrow, the team ___ the phone.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'In a few days, he ___ the lecture.\nA) drives\nB) drove\nC) will drive\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Next week, the teacher ___ the computer.\nA) cooks\nB) cooked\nC) will cook\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Later today, the engineer ___ the exam.\nA) painted\nB) paints\nC) will paint\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'In the near future, the artists ___ the lecture.\nA) slept\nB) sleeps\nC) will sleep\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Next year, the child ___ the test.\nA) thought\nB) thinks\nC) will think\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'By next year, the teacher ___ the problem.\nA) builds\nB) built\nC) will build\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Shortly, the musician ___ the house.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Soon, the cooks ___ the ball.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Next week, the cat ___ the lecture.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Soon, I ___ a letter.\nA) will dance\nB) dance\nC) danced\nAnswer:' → Pred: 'A' | Gold: 'A'
# {'past': 0.7333333333333333, 'present': 0.6333333333333333, 'future': 0.8}

# %% [markdown]
# Layer 15

# %%
# Run with SAEs
alpha = 0
accuracy = evaluate_with_saes(dev_data, alpha)
print(accuracy)
# Out:
# Prompt: 'Last night, I ___ the journal.\nA) drew\nB) will draw\nC) draw\nAnswer:' → Pred: 'draw' | Gold: 'A'
# Prompt: 'Earlier today, she ___ the lecture.\nA) will explore\nB) explored\nC) explores\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Yesterday, I ___ the ball.\nA) watched\nB) will watch\nC) watch\nAnswer:' → Pred: 'watch' | Gold: 'A'
# Prompt: 'Last summer, the dog ___ the exam.\nA) summarizes\nB) summarized\nC) will summarize\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'A week ago, the musician ___ the cake.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'draw' | Gold: 'A'
# Prompt: 'Back then, the students ___ the cake.\nA) will speak\nB) spoke\nC) speaks\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Last night, he ___ the game.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: 'will' | Gold: 'C'
# Prompt: 'Once upon a time, the birds ___ a letter.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Back then, he ___ the phone.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: '__' | Gold: 'B'
# Prompt: 'Once upon a time, the dog ___ the exam.\nA) meowed\nB) will meow\nC) meows\nAnswer:' → Pred: 'dog' | Gold: 'A'
# Prompt: 'In my childhood, he ___ the book.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: 'will' | Gold: 'C'
# Prompt: 'Last Monday, the driver ___ the presentation.\nA) eats\nB) will eat\nC) ate\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'A week ago, the cooks ___ the cake.\nA) summarized\nB) will summarize\nC) summarizes\nAnswer:' → Pred: 'will' | Gold: 'A'
# Prompt: 'Last summer, the cat ___ the movie.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last summer, the cat ___ the lecture.\nA) baked\nB) will bake\nC) bakes\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Yesterday, the students ___ the game.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Once upon a time, the athletes ___ the meeting.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Back then, the driver ___ the house.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'Driver' | Gold: 'C'
# Prompt: 'A week ago, the robot ___ the phone.\nA) sings\nB) sung\nC) will sing\nAnswer:' → Pred: 'sing' | Gold: 'B'
# Prompt: 'Once upon a time, the engineer ___ the presentation.\nA) will listen\nB) listened\nC) listens\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last night, you ___ the homework.\nA) spoke\nB) speak\nC) will speak\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Back then, the parents ___ the ball.\nA) sleeps\nB) will sleep\nC) slept\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Last summer, the birds ___ the phone.\nA) smiled\nB) smiles\nC) will smile\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Last summer, the birds ___ the painting.\nA) will summarize\nB) summarizes\nC) summarized\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In my childhood, the artists ___ the movie.\nA) will teach\nB) taught\nC) teaches\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last summer, they ___ the computer.\nA) walk\nB) walked\nC) will walk\nAnswer:' → Pred: 'walk' | Gold: 'B'
# Prompt: 'Last summer, the parents ___ the problem.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Last summer, the team ___ the mailman.\nA) likes\nB) will like\nC) liked\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Yesterday, she ___ the presentation.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'A week ago, the child ___ the ball.\nA) chirps\nB) chirped\nC) will chirp\nAnswer:' → Pred: 'will' | Gold: 'B'
# Prompt: 'Always, the robot ___ the painting.\nA) will write\nB) wrote\nC) writes\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Every Monday, they ___ the cake.\nA) design\nB) designed\nC) will design\nAnswer:' → Pred: 'design' | Gold: 'A'
# Prompt: 'Usually, the robot ___ the painting.\nA) plays\nB) played\nC) will play\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Every Saturday, the cooks ___ the project.\nA) jumps\nB) will jump\nC) jumped\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Always, the cat ___ the book.\nA) will meow\nB) meows\nC) meowed\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Every morning, the robot ___ the book.\nA) carried\nB) will carry\nC) carries\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Always, the athletes ___ the project.\nA) barked\nB) will bark\nC) barks\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Everyday, the students ___ the ball.\nA) will deliver\nB) delivered\nC) delivers\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'In this instant, the dog ___ the phone.\nA) writes\nB) wrote\nC) will write\nAnswer:' → Pred: 'write' | Gold: 'A'
# Prompt: 'Usually, the company ___ the car.\nA) played\nB) will play\nC) plays\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Every Saturday, the doctors ___ the car.\nA) will dream\nB) dreams\nC) dreamt\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Always, you ___ the game.\nA) drove\nB) will drive\nC) drive\nAnswer:' → Pred: 'will' | Gold: 'C'
# Prompt: 'Usually, the dog ___ the phone.\nA) will solve\nB) solved\nC) solves\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Often, the birds ___ the house.\nA) will dance\nB) danced\nC) dances\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Every Monday, she ___ a letter.\nA) summarized\nB) summarizes\nC) will summarize\nAnswer:' → Pred: 'summarized' | Gold: 'B'
# Prompt: 'Always, the cat ___ the movie.\nA) dreams\nB) will dream\nC) dreamt\nAnswer:' → Pred: 'Cat' | Gold: 'A'
# Prompt: 'Usually, the engineer ___ a letter.\nA) will eat\nB) eats\nC) ate\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Every Saturday, the birds ___ the house.\nA) paints\nB) will paint\nC) painted\nAnswer:' → Pred: 'paint' | Gold: 'A'
# Prompt: 'Often, the dog ___ the test.\nA) watched\nB) will watch\nC) watches\nAnswer:' → Pred: 'test' | Gold: 'C'
# Prompt: 'Sometimes, you ___ a letter.\nA) will carry\nB) carry\nC) carried\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Everyday, the team ___ the ball.\nA) drank\nB) will drink\nC) drinks\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Usually, the engineer ___ the homework.\nA) saw\nB) will see\nC) sees\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Every morning, he ___ the car.\nA) constructs\nB) constructed\nC) will construct\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Every week, the dog ___ the lecture.\nA) will bake\nB) baked\nC) bakes\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Every Saturday, we ___ the lecture.\nA) summarize\nB) will summarize\nC) summarized\nAnswer:' → Pred: 'will' | Gold: 'A'
# Prompt: 'Sometimes, he ___ the mailman.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the robot ___ the problem.\nA) will deliver\nB) delivers\nC) delivered\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Sometimes, he ___ the book.\nA) will jump\nB) jumps\nC) jumped\nAnswer:' → Pred: 'will' | Gold: 'B'
# Prompt: 'In this instant, the robot ___ the exam.\nA) cooked\nB) cooks\nC) will cook\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Every Monday, the teacher ___ the lecture.\nA) will walk\nB) walked\nC) walks\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Next week, she ___ the journal.\nA) will discover\nB) discovered\nC) discovers\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, the parents ___ the problem.\nA) will drive\nB) drove\nC) drives\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Before long, the company ___ the cake.\nA) will bark\nB) barked\nC) barks\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, you ___ the mailman.\nA) will drive\nB) drove\nC) drive\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Soon, the musician ___ the phone.\nA) built\nB) builds\nC) will build\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Next week, he ___ the exam.\nA) spoke\nB) speaks\nC) will speak\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Later today, the child ___ the phone.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Tomorrow, the teacher ___ the presentation.\nA) will cry\nB) cries\nC) cried\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'In the near future, the cooks ___ the homework.\nA) flies\nB) flew\nC) will fly\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next year, we ___ the book.\nA) will eat\nB) ate\nC) eat\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Tomorrow, they ___ the journal.\nA) will drive\nB) drive\nC) drove\nAnswer:' → Pred: 'will' | Gold: 'A'
# Prompt: 'By next year, they ___ the exam.\nA) will walk\nB) walk\nC) walked\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Shortly, the cat ___ the problem.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'Cat' | Gold: 'B'
# Prompt: 'In the near future, the cat ___ the mailman.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Later today, the birds ___ the ball.\nA) draws\nB) will draw\nC) drew\nAnswer:' → Pred: 'birds' | Gold: 'B'
# Prompt: 'Before long, the students ___ the mailman.\nA) will jog\nB) jogs\nC) jogged\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Next year, the birds ___ a letter.\nA) walks\nB) walked\nC) will walk\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Later today, the students ___ the car.\nA) liked\nB) likes\nC) will like\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'In a few days, the child ___ the problem.\nA) will sing\nB) sung\nC) sings\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Tomorrow, the team ___ the phone.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'In a few days, he ___ the lecture.\nA) drives\nB) drove\nC) will drive\nAnswer:' → Pred: 'drive' | Gold: 'C'
# Prompt: 'Next week, the teacher ___ the computer.\nA) cooks\nB) cooked\nC) will cook\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Later today, the engineer ___ the exam.\nA) painted\nB) paints\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In the near future, the artists ___ the lecture.\nA) slept\nB) sleeps\nC) will sleep\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Next year, the child ___ the test.\nA) thought\nB) thinks\nC) will think\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'By next year, the teacher ___ the problem.\nA) builds\nB) built\nC) will build\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Shortly, the musician ___ the house.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'Watch' | Gold: 'C'
# Prompt: 'Soon, the cooks ___ the ball.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'paint' | Gold: 'C'
# Prompt: 'Next week, the cat ___ the lecture.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'Cat' | Gold: 'B'
# Prompt: 'Soon, I ___ a letter.\nA) will dance\nB) dance\nC) danced\nAnswer:' → Pred: 'A' | Gold: 'A'
# {'past': 0.26666666666666666, 'present': 0.13333333333333333, 'future': 0.43333333333333335}

# %%
# Run with SAEs
alpha = 1
accuracy = evaluate_with_saes(pilot, alpha)
print(accuracy)
# Out:
# Prompt: 'Last night, I ___ the journal.\nA) drew\nB) will draw\nC) draw\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Earlier today, she ___ the lecture.\nA) will explore\nB) explored\nC) explores\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Yesterday, I ___ the ball.\nA) watched\nB) will watch\nC) watch\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Last summer, the dog ___ the exam.\nA) summarizes\nB) summarized\nC) will summarize\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'A week ago, the musician ___ the cake.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'draw' | Gold: 'A'
# Prompt: 'Always, the robot ___ the painting.\nA) will write\nB) wrote\nC) writes\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Every Monday, they ___ the cake.\nA) design\nB) designed\nC) will design\nAnswer:' → Pred: 'design' | Gold: 'A'
# Prompt: 'Usually, the robot ___ the painting.\nA) plays\nB) played\nC) will play\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Every Saturday, the cooks ___ the project.\nA) jumps\nB) will jump\nC) jumped\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Always, the cat ___ the book.\nA) will meow\nB) meows\nC) meowed\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Next week, she ___ the journal.\nA) will discover\nB) discovered\nC) discovers\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, the parents ___ the problem.\nA) will drive\nB) drove\nC) drives\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Before long, the company ___ the cake.\nA) will bark\nB) barked\nC) barks\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, you ___ the mailman.\nA) will drive\nB) drove\nC) drive\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Soon, the musician ___ the phone.\nA) built\nB) builds\nC) will build\nAnswer:' → Pred: 'A' | Gold: 'C'
# {'past': 0.6, 'present': 0.4, 'future': 0.8}

# %% [markdown]
# Layer 16

# %%
# Run with SAEs
alpha = 2.0
accuracy = evaluate_with_saes(dev_data, alpha)
print(accuracy)
# Out:
# Prompt: 'Last night, I ___ the journal.\nA) drew\nB) will draw\nC) draw\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Earlier today, she ___ the lecture.\nA) will explore\nB) explored\nC) explores\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Yesterday, I ___ the ball.\nA) watched\nB) will watch\nC) watch\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Last summer, the dog ___ the exam.\nA) summarizes\nB) summarized\nC) will summarize\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'A week ago, the musician ___ the cake.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Back then, the students ___ the cake.\nA) will speak\nB) spoke\nC) speaks\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last night, he ___ the game.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Once upon a time, the birds ___ a letter.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Back then, he ___ the phone.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Once upon a time, the dog ___ the exam.\nA) meowed\nB) will meow\nC) meows\nAnswer:' → Pred: 'dog' | Gold: 'A'
# Prompt: 'In my childhood, he ___ the book.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last Monday, the driver ___ the presentation.\nA) eats\nB) will eat\nC) ate\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'A week ago, the cooks ___ the cake.\nA) summarized\nB) will summarize\nC) summarizes\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Last summer, the cat ___ the movie.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last summer, the cat ___ the lecture.\nA) baked\nB) will bake\nC) bakes\nAnswer:' → Pred: 'Cat' | Gold: 'A'
# Prompt: 'Yesterday, the students ___ the game.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Once upon a time, the athletes ___ the meeting.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Back then, the driver ___ the house.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'A week ago, the robot ___ the phone.\nA) sings\nB) sung\nC) will sing\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Once upon a time, the engineer ___ the presentation.\nA) will listen\nB) listened\nC) listens\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last night, you ___ the homework.\nA) spoke\nB) speak\nC) will speak\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Back then, the parents ___ the ball.\nA) sleeps\nB) will sleep\nC) slept\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last summer, the birds ___ the phone.\nA) smiled\nB) smiles\nC) will smile\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Last summer, the birds ___ the painting.\nA) will summarize\nB) summarizes\nC) summarized\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In my childhood, the artists ___ the movie.\nA) will teach\nB) taught\nC) teaches\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last summer, they ___ the computer.\nA) walk\nB) walked\nC) will walk\nAnswer:' → Pred: 'walk' | Gold: 'B'
# Prompt: 'Last summer, the parents ___ the problem.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last summer, the team ___ the mailman.\nA) likes\nB) will like\nC) liked\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Yesterday, she ___ the presentation.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'A week ago, the child ___ the ball.\nA) chirps\nB) chirped\nC) will chirp\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the robot ___ the painting.\nA) will write\nB) wrote\nC) writes\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Monday, they ___ the cake.\nA) design\nB) designed\nC) will design\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Usually, the robot ___ the painting.\nA) plays\nB) played\nC) will play\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Every Saturday, the cooks ___ the project.\nA) jumps\nB) will jump\nC) jumped\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Always, the cat ___ the book.\nA) will meow\nB) meows\nC) meowed\nAnswer:' → Pred: 'Cat' | Gold: 'B'
# Prompt: 'Every morning, the robot ___ the book.\nA) carried\nB) will carry\nC) carries\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Always, the athletes ___ the project.\nA) barked\nB) will bark\nC) barks\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Everyday, the students ___ the ball.\nA) will deliver\nB) delivered\nC) delivers\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'In this instant, the dog ___ the phone.\nA) writes\nB) wrote\nC) will write\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Usually, the company ___ the car.\nA) played\nB) will play\nC) plays\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Saturday, the doctors ___ the car.\nA) will dream\nB) dreams\nC) dreamt\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Always, you ___ the game.\nA) drove\nB) will drive\nC) drive\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Usually, the dog ___ the phone.\nA) will solve\nB) solved\nC) solves\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Often, the birds ___ the house.\nA) will dance\nB) danced\nC) dances\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Monday, she ___ a letter.\nA) summarized\nB) summarizes\nC) will summarize\nAnswer:' → Pred: 'summarizes' | Gold: 'B'
# Prompt: 'Always, the cat ___ the movie.\nA) dreams\nB) will dream\nC) dreamt\nAnswer:' → Pred: 'Cat' | Gold: 'A'
# Prompt: 'Usually, the engineer ___ a letter.\nA) will eat\nB) eats\nC) ate\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Every Saturday, the birds ___ the house.\nA) paints\nB) will paint\nC) painted\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Often, the dog ___ the test.\nA) watched\nB) will watch\nC) watches\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Sometimes, you ___ a letter.\nA) will carry\nB) carry\nC) carried\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Everyday, the team ___ the ball.\nA) drank\nB) will drink\nC) drinks\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Usually, the engineer ___ the homework.\nA) saw\nB) will see\nC) sees\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every morning, he ___ the car.\nA) constructs\nB) constructed\nC) will construct\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Every week, the dog ___ the lecture.\nA) will bake\nB) baked\nC) bakes\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Saturday, we ___ the lecture.\nA) summarize\nB) will summarize\nC) summarized\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Sometimes, he ___ the mailman.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the robot ___ the problem.\nA) will deliver\nB) delivers\nC) delivered\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Sometimes, he ___ the book.\nA) will jump\nB) jumps\nC) jumped\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'In this instant, the robot ___ the exam.\nA) cooked\nB) cooks\nC) will cook\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Every Monday, the teacher ___ the lecture.\nA) will walk\nB) walked\nC) walks\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, she ___ the journal.\nA) will discover\nB) discovered\nC) discovers\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, the parents ___ the problem.\nA) will drive\nB) drove\nC) drives\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Before long, the company ___ the cake.\nA) will bark\nB) barked\nC) barks\nAnswer:' → Pred: 'b' | Gold: 'A'
# Prompt: 'By next year, you ___ the mailman.\nA) will drive\nB) drove\nC) drive\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Soon, the musician ___ the phone.\nA) built\nB) builds\nC) will build\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, he ___ the exam.\nA) spoke\nB) speaks\nC) will speak\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Later today, the child ___ the phone.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Tomorrow, the teacher ___ the presentation.\nA) will cry\nB) cries\nC) cried\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'In the near future, the cooks ___ the homework.\nA) flies\nB) flew\nC) will fly\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next year, we ___ the book.\nA) will eat\nB) ate\nC) eat\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Tomorrow, they ___ the journal.\nA) will drive\nB) drive\nC) drove\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'By next year, they ___ the exam.\nA) will walk\nB) walk\nC) walked\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Shortly, the cat ___ the problem.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'cat' | Gold: 'B'
# Prompt: 'In the near future, the cat ___ the mailman.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'Cat' | Gold: 'A'
# Prompt: 'Later today, the birds ___ the ball.\nA) draws\nB) will draw\nC) drew\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Before long, the students ___ the mailman.\nA) will jog\nB) jogs\nC) jogged\nAnswer:' → Pred: 'j' | Gold: 'A'
# Prompt: 'Next year, the birds ___ a letter.\nA) walks\nB) walked\nC) will walk\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Later today, the students ___ the car.\nA) liked\nB) likes\nC) will like\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In a few days, the child ___ the problem.\nA) will sing\nB) sung\nC) sings\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Tomorrow, the team ___ the phone.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'In a few days, he ___ the lecture.\nA) drives\nB) drove\nC) will drive\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, the teacher ___ the computer.\nA) cooks\nB) cooked\nC) will cook\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Later today, the engineer ___ the exam.\nA) painted\nB) paints\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In the near future, the artists ___ the lecture.\nA) slept\nB) sleeps\nC) will sleep\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next year, the child ___ the test.\nA) thought\nB) thinks\nC) will think\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'By next year, the teacher ___ the problem.\nA) builds\nB) built\nC) will build\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Shortly, the musician ___ the house.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Soon, the cooks ___ the ball.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, the cat ___ the lecture.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'Cat' | Gold: 'B'
# Prompt: 'Soon, I ___ a letter.\nA) will dance\nB) dance\nC) danced\nAnswer:' → Pred: 'B' | Gold: 'A'
# {'past': 0.3, 'present': 0.23333333333333334, 'future': 0.1}

# %%
# Run with SAEs
alpha = 0.1
accuracy = evaluate_with_saes(dev_data, alpha)
print(accuracy)
# Out:
# Prompt: 'Last night, I ___ the journal.\nA) drew\nB) will draw\nC) draw\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Earlier today, she ___ the lecture.\nA) will explore\nB) explored\nC) explores\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Yesterday, I ___ the ball.\nA) watched\nB) will watch\nC) watch\nAnswer:' → Pred: 'watch' | Gold: 'A'
# Prompt: 'Last summer, the dog ___ the exam.\nA) summarizes\nB) summarized\nC) will summarize\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'A week ago, the musician ___ the cake.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Back then, the students ___ the cake.\nA) will speak\nB) spoke\nC) speaks\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last night, he ___ the game.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Once upon a time, the birds ___ a letter.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Back then, he ___ the phone.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Once upon a time, the dog ___ the exam.\nA) meowed\nB) will meow\nC) meows\nAnswer:' → Pred: 'dog' | Gold: 'A'
# Prompt: 'In my childhood, he ___ the book.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last Monday, the driver ___ the presentation.\nA) eats\nB) will eat\nC) ate\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'A week ago, the cooks ___ the cake.\nA) summarized\nB) will summarize\nC) summarizes\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Last summer, the cat ___ the movie.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last summer, the cat ___ the lecture.\nA) baked\nB) will bake\nC) bakes\nAnswer:' → Pred: 'Cat' | Gold: 'A'
# Prompt: 'Yesterday, the students ___ the game.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Once upon a time, the athletes ___ the meeting.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Back then, the driver ___ the house.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'A week ago, the robot ___ the phone.\nA) sings\nB) sung\nC) will sing\nAnswer:' → Pred: 'sing' | Gold: 'B'
# Prompt: 'Once upon a time, the engineer ___ the presentation.\nA) will listen\nB) listened\nC) listens\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last night, you ___ the homework.\nA) spoke\nB) speak\nC) will speak\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Back then, the parents ___ the ball.\nA) sleeps\nB) will sleep\nC) slept\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last summer, the birds ___ the phone.\nA) smiled\nB) smiles\nC) will smile\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Last summer, the birds ___ the painting.\nA) will summarize\nB) summarizes\nC) summarized\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In my childhood, the artists ___ the movie.\nA) will teach\nB) taught\nC) teaches\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last summer, they ___ the computer.\nA) walk\nB) walked\nC) will walk\nAnswer:' → Pred: 'walk' | Gold: 'B'
# Prompt: 'Last summer, the parents ___ the problem.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Last summer, the team ___ the mailman.\nA) likes\nB) will like\nC) liked\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Yesterday, she ___ the presentation.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'A week ago, the child ___ the ball.\nA) chirps\nB) chirped\nC) will chirp\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the robot ___ the painting.\nA) will write\nB) wrote\nC) writes\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Monday, they ___ the cake.\nA) design\nB) designed\nC) will design\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Usually, the robot ___ the painting.\nA) plays\nB) played\nC) will play\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Every Saturday, the cooks ___ the project.\nA) jumps\nB) will jump\nC) jumped\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Always, the cat ___ the book.\nA) will meow\nB) meows\nC) meowed\nAnswer:' → Pred: 'Cat' | Gold: 'B'
# Prompt: 'Every morning, the robot ___ the book.\nA) carried\nB) will carry\nC) carries\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Always, the athletes ___ the project.\nA) barked\nB) will bark\nC) barks\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Everyday, the students ___ the ball.\nA) will deliver\nB) delivered\nC) delivers\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'In this instant, the dog ___ the phone.\nA) writes\nB) wrote\nC) will write\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Usually, the company ___ the car.\nA) played\nB) will play\nC) plays\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Saturday, the doctors ___ the car.\nA) will dream\nB) dreams\nC) dreamt\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Always, you ___ the game.\nA) drove\nB) will drive\nC) drive\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Usually, the dog ___ the phone.\nA) will solve\nB) solved\nC) solves\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Often, the birds ___ the house.\nA) will dance\nB) danced\nC) dances\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Monday, she ___ a letter.\nA) summarized\nB) summarizes\nC) will summarize\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the cat ___ the movie.\nA) dreams\nB) will dream\nC) dreamt\nAnswer:' → Pred: 'Cat' | Gold: 'A'
# Prompt: 'Usually, the engineer ___ a letter.\nA) will eat\nB) eats\nC) ate\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Every Saturday, the birds ___ the house.\nA) paints\nB) will paint\nC) painted\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Often, the dog ___ the test.\nA) watched\nB) will watch\nC) watches\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Sometimes, you ___ a letter.\nA) will carry\nB) carry\nC) carried\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Everyday, the team ___ the ball.\nA) drank\nB) will drink\nC) drinks\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Usually, the engineer ___ the homework.\nA) saw\nB) will see\nC) sees\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every morning, he ___ the car.\nA) constructs\nB) constructed\nC) will construct\nAnswer:' → Pred: 'construct' | Gold: 'A'
# Prompt: 'Every week, the dog ___ the lecture.\nA) will bake\nB) baked\nC) bakes\nAnswer:' → Pred: 'b' | Gold: 'C'
# Prompt: 'Every Saturday, we ___ the lecture.\nA) summarize\nB) will summarize\nC) summarized\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Sometimes, he ___ the mailman.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the robot ___ the problem.\nA) will deliver\nB) delivers\nC) delivered\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Sometimes, he ___ the book.\nA) will jump\nB) jumps\nC) jumped\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'In this instant, the robot ___ the exam.\nA) cooked\nB) cooks\nC) will cook\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Every Monday, the teacher ___ the lecture.\nA) will walk\nB) walked\nC) walks\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, she ___ the journal.\nA) will discover\nB) discovered\nC) discovers\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'By next year, the parents ___ the problem.\nA) will drive\nB) drove\nC) drives\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Before long, the company ___ the cake.\nA) will bark\nB) barked\nC) barks\nAnswer:' → Pred: 'b' | Gold: 'A'
# Prompt: 'By next year, you ___ the mailman.\nA) will drive\nB) drove\nC) drive\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Soon, the musician ___ the phone.\nA) built\nB) builds\nC) will build\nAnswer:' → Pred: 'built' | Gold: 'C'
# Prompt: 'Next week, he ___ the exam.\nA) spoke\nB) speaks\nC) will speak\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Later today, the child ___ the phone.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Tomorrow, the teacher ___ the presentation.\nA) will cry\nB) cries\nC) cried\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'In the near future, the cooks ___ the homework.\nA) flies\nB) flew\nC) will fly\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next year, we ___ the book.\nA) will eat\nB) ate\nC) eat\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Tomorrow, they ___ the journal.\nA) will drive\nB) drive\nC) drove\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'By next year, they ___ the exam.\nA) will walk\nB) walk\nC) walked\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Shortly, the cat ___ the problem.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'cat' | Gold: 'B'
# Prompt: 'In the near future, the cat ___ the mailman.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'Cat' | Gold: 'A'
# Prompt: 'Later today, the birds ___ the ball.\nA) draws\nB) will draw\nC) drew\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Before long, the students ___ the mailman.\nA) will jog\nB) jogs\nC) jogged\nAnswer:' → Pred: 'j' | Gold: 'A'
# Prompt: 'Next year, the birds ___ a letter.\nA) walks\nB) walked\nC) will walk\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Later today, the students ___ the car.\nA) liked\nB) likes\nC) will like\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In a few days, the child ___ the problem.\nA) will sing\nB) sung\nC) sings\nAnswer:' → Pred: 'sing' | Gold: 'A'
# Prompt: 'Tomorrow, the team ___ the phone.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'team' | Gold: 'A'
# Prompt: 'In a few days, he ___ the lecture.\nA) drives\nB) drove\nC) will drive\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, the teacher ___ the computer.\nA) cooks\nB) cooked\nC) will cook\nAnswer:' → Pred: 'teacher' | Gold: 'C'
# Prompt: 'Later today, the engineer ___ the exam.\nA) painted\nB) paints\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In the near future, the artists ___ the lecture.\nA) slept\nB) sleeps\nC) will sleep\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next year, the child ___ the test.\nA) thought\nB) thinks\nC) will think\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'By next year, the teacher ___ the problem.\nA) builds\nB) built\nC) will build\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Shortly, the musician ___ the house.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'watch' | Gold: 'C'
# Prompt: 'Soon, the cooks ___ the ball.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, the cat ___ the lecture.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'Cat' | Gold: 'B'
# Prompt: 'Soon, I ___ a letter.\nA) will dance\nB) dance\nC) danced\nAnswer:' → Pred: 'dance' | Gold: 'A'
# {'past': 0.3, 'present': 0.23333333333333334, 'future': 0.03333333333333333}

# %% [markdown]
# #### Layer 15, 16

# %%
# Run with SAEs
alpha = 1.5
accuracy = evaluate_with_saes(dev_data, alpha)
print(accuracy)
# Out:
# Prompt: 'Last night, I ___ the journal.\nA) drew\nB) will draw\nC) draw\nAnswer:' → Pred: '__' | Gold: 'A'
# Prompt: 'Earlier today, she ___ the lecture.\nA) will explore\nB) explored\nC) explores\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Yesterday, I ___ the ball.\nA) watched\nB) will watch\nC) watch\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Last summer, the dog ___ the exam.\nA) summarizes\nB) summarized\nC) will summarize\nAnswer:' → Pred: '______' | Gold: 'B'
# Prompt: 'A week ago, the musician ___ the cake.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: '(' | Gold: 'A'
# Prompt: 'Back then, the students ___ the cake.\nA) will speak\nB) spoke\nC) speaks\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Last night, he ___ the game.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'Once upon a time, the birds ___ a letter.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'a' | Gold: 'A'
# Prompt: 'Back then, he ___ the phone.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Once upon a time, the dog ___ the exam.\nA) meowed\nB) will meow\nC) meows\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'In my childhood, he ___ the book.\nA) walks\nB) will walk\nC) walked\nAnswer:' → Pred: '(' | Gold: 'C'
# Prompt: 'Last Monday, the driver ___ the presentation.\nA) eats\nB) will eat\nC) ate\nAnswer:' → Pred: '______' | Gold: 'C'
# Prompt: 'A week ago, the cooks ___ the cake.\nA) summarized\nB) will summarize\nC) summarizes\nAnswer:' → Pred: '__' | Gold: 'A'
# Prompt: 'Last summer, the cat ___ the movie.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'Last summer, the cat ___ the lecture.\nA) baked\nB) will bake\nC) bakes\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Yesterday, the students ___ the game.\nA) drew\nB) will draw\nC) draws\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Once upon a time, the athletes ___ the meeting.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Back then, the driver ___ the house.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'A week ago, the robot ___ the phone.\nA) sings\nB) sung\nC) will sing\nAnswer:' → Pred: '__' | Gold: 'B'
# Prompt: 'Once upon a time, the engineer ___ the presentation.\nA) will listen\nB) listened\nC) listens\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Last night, you ___ the homework.\nA) spoke\nB) speak\nC) will speak\nAnswer:' → Pred: '(' | Gold: 'A'
# Prompt: 'Back then, the parents ___ the ball.\nA) sleeps\nB) will sleep\nC) slept\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'Last summer, the birds ___ the phone.\nA) smiled\nB) smiles\nC) will smile\nAnswer:' → Pred: '__' | Gold: 'A'
# Prompt: 'Last summer, the birds ___ the painting.\nA) will summarize\nB) summarizes\nC) summarized\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'In my childhood, the artists ___ the movie.\nA) will teach\nB) taught\nC) teaches\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Last summer, they ___ the computer.\nA) walk\nB) walked\nC) will walk\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Last summer, the parents ___ the problem.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Last summer, the team ___ the mailman.\nA) likes\nB) will like\nC) liked\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Yesterday, she ___ the presentation.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'A week ago, the child ___ the ball.\nA) chirps\nB) chirped\nC) will chirp\nAnswer:' → Pred: '(' | Gold: 'B'
# Prompt: 'Always, the robot ___ the painting.\nA) will write\nB) wrote\nC) writes\nAnswer:' → Pred: 'the' | Gold: 'C'
# Prompt: 'Every Monday, they ___ the cake.\nA) design\nB) designed\nC) will design\nAnswer:' → Pred: '__' | Gold: 'A'
# Prompt: 'Usually, the robot ___ the painting.\nA) plays\nB) played\nC) will play\nAnswer:' → Pred: '(' | Gold: 'A'
# Prompt: 'Every Saturday, the cooks ___ the project.\nA) jumps\nB) will jump\nC) jumped\nAnswer:' → Pred: '______' | Gold: 'A'
# Prompt: 'Always, the cat ___ the book.\nA) will meow\nB) meows\nC) meowed\nAnswer:' → Pred: '(' | Gold: 'B'
# Prompt: 'Every morning, the robot ___ the book.\nA) carried\nB) will carry\nC) carries\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'Always, the athletes ___ the project.\nA) barked\nB) will bark\nC) barks\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Everyday, the students ___ the ball.\nA) will deliver\nB) delivered\nC) delivers\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In this instant, the dog ___ the phone.\nA) writes\nB) wrote\nC) will write\nAnswer:' → Pred: '__' | Gold: 'A'
# Prompt: 'Usually, the company ___ the car.\nA) played\nB) will play\nC) plays\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every Saturday, the doctors ___ the car.\nA) will dream\nB) dreams\nC) dreamt\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, you ___ the game.\nA) drove\nB) will drive\nC) drive\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Usually, the dog ___ the phone.\nA) will solve\nB) solved\nC) solves\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'Often, the birds ___ the house.\nA) will dance\nB) danced\nC) dances\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'Every Monday, she ___ a letter.\nA) summarized\nB) summarizes\nC) will summarize\nAnswer:' → Pred: 'a' | Gold: 'B'
# Prompt: 'Always, the cat ___ the movie.\nA) dreams\nB) will dream\nC) dreamt\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Usually, the engineer ___ a letter.\nA) will eat\nB) eats\nC) ate\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Every Saturday, the birds ___ the house.\nA) paints\nB) will paint\nC) painted\nAnswer:' → Pred: '______' | Gold: 'A'
# Prompt: 'Often, the dog ___ the test.\nA) watched\nB) will watch\nC) watches\nAnswer:' → Pred: '(' | Gold: 'C'
# Prompt: 'Sometimes, you ___ a letter.\nA) will carry\nB) carry\nC) carried\nAnswer:' → Pred: 'a' | Gold: 'B'
# Prompt: 'Everyday, the team ___ the ball.\nA) drank\nB) will drink\nC) drinks\nAnswer:' → Pred: '__' | Gold: 'C'
# Prompt: 'Usually, the engineer ___ the homework.\nA) saw\nB) will see\nC) sees\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Every morning, he ___ the car.\nA) constructs\nB) constructed\nC) will construct\nAnswer:' → Pred: 'C' | Gold: 'A'
# Prompt: 'Every week, the dog ___ the lecture.\nA) will bake\nB) baked\nC) bakes\nAnswer:' → Pred: '______' | Gold: 'C'
# Prompt: 'Every Saturday, we ___ the lecture.\nA) summarize\nB) will summarize\nC) summarized\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Sometimes, he ___ the mailman.\nA) taught\nB) teaches\nC) will teach\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Always, the robot ___ the problem.\nA) will deliver\nB) delivers\nC) delivered\nAnswer:' → Pred: 'A' | Gold: 'B'
# Prompt: 'Sometimes, he ___ the book.\nA) will jump\nB) jumps\nC) jumped\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'In this instant, the robot ___ the exam.\nA) cooked\nB) cooks\nC) will cook\nAnswer:' → Pred: '(' | Gold: 'B'
# Prompt: 'Every Monday, the teacher ___ the lecture.\nA) will walk\nB) walked\nC) walks\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, she ___ the journal.\nA) will discover\nB) discovered\nC) discovers\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, the parents ___ the problem.\nA) will drive\nB) drove\nC) drives\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Before long, the company ___ the cake.\nA) will bark\nB) barked\nC) barks\nAnswer:' → Pred: 'b' | Gold: 'A'
# Prompt: 'By next year, you ___ the mailman.\nA) will drive\nB) drove\nC) drive\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Soon, the musician ___ the phone.\nA) built\nB) builds\nC) will build\nAnswer:' → Pred: 'the' | Gold: 'C'
# Prompt: 'Next week, he ___ the exam.\nA) spoke\nB) speaks\nC) will speak\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Later today, the child ___ the phone.\nA) will speak\nB) speaks\nC) spoke\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Tomorrow, the teacher ___ the presentation.\nA) will cry\nB) cries\nC) cried\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'In the near future, the cooks ___ the homework.\nA) flies\nB) flew\nC) will fly\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next year, we ___ the book.\nA) will eat\nB) ate\nC) eat\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'Tomorrow, they ___ the journal.\nA) will drive\nB) drive\nC) drove\nAnswer:' → Pred: 'A' | Gold: 'A'
# Prompt: 'By next year, they ___ the exam.\nA) will walk\nB) walk\nC) walked\nAnswer:' → Pred: '' | Gold: 'A'
# Prompt: 'Shortly, the cat ___ the problem.\nA) teaches\nB) will teach\nC) taught\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'In the near future, the cat ___ the mailman.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Later today, the birds ___ the ball.\nA) draws\nB) will draw\nC) drew\nAnswer:' → Pred: 'C' | Gold: 'B'
# Prompt: 'Before long, the students ___ the mailman.\nA) will jog\nB) jogs\nC) jogged\nAnswer:' → Pred: 'j' | Gold: 'A'
# Prompt: 'Next year, the birds ___ a letter.\nA) walks\nB) walked\nC) will walk\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Later today, the students ___ the car.\nA) liked\nB) likes\nC) will like\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'In a few days, the child ___ the problem.\nA) will sing\nB) sung\nC) sings\nAnswer:' → Pred: 'B' | Gold: 'A'
# Prompt: 'Tomorrow, the team ___ the phone.\nA) will construct\nB) constructed\nC) constructs\nAnswer:' → Pred: 'The' | Gold: 'A'
# Prompt: 'In a few days, he ___ the lecture.\nA) drives\nB) drove\nC) will drive\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Next week, the teacher ___ the computer.\nA) cooks\nB) cooked\nC) will cook\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'Later today, the engineer ___ the exam.\nA) painted\nB) paints\nC) will paint\nAnswer:' → Pred: '______' | Gold: 'C'
# Prompt: 'In the near future, the artists ___ the lecture.\nA) slept\nB) sleeps\nC) will sleep\nAnswer:' → Pred: 'C' | Gold: 'C'
# Prompt: 'Next year, the child ___ the test.\nA) thought\nB) thinks\nC) will think\nAnswer:' → Pred: 'A' | Gold: 'C'
# Prompt: 'By next year, the teacher ___ the problem.\nA) builds\nB) built\nC) will build\nAnswer:' → Pred: 'B' | Gold: 'C'
# Prompt: 'Shortly, the musician ___ the house.\nA) watches\nB) watched\nC) will watch\nAnswer:' → Pred: 'the' | Gold: 'C'
# Prompt: 'Soon, the cooks ___ the ball.\nA) paints\nB) painted\nC) will paint\nAnswer:' → Pred: 'The' | Gold: 'C'
# Prompt: 'Next week, the cat ___ the lecture.\nA) cooked\nB) will cook\nC) cooks\nAnswer:' → Pred: 'B' | Gold: 'B'
# Prompt: 'Soon, I ___ a letter.\nA) will dance\nB) dance\nC) danced\nAnswer:' → Pred: 'a' | Gold: 'A'
# {'past': 0.2, 'present': 0.13333333333333333, 'future': 0.3}
