# %%
import numpy as np
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from pyvene import (
    ConstantSourceIntervention,
    LocalistRepresentationIntervention,
    IntervenableConfig,
    RepresentationConfig,
    IntervenableModel,
    embed_to_distrib,
    top_vals,
    VanillaIntervention,
)
import torch.nn.functional as F
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# nnsight is not detected. Please install via 'pip install nnsight' for nnsight backend.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# Load Llama-3.1 8B
MODEL = "meta-llama/Llama-3.1-8b"
HF_TOKEN = "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"
tokenizer = AutoTokenizer.from_pretrained(MODEL, token=HF_TOKEN)
model = AutoModelForCausalLM.from_pretrained(MODEL, device_map="auto", torch_dtype=torch.float16, token=HF_TOKEN)
model.eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %% [markdown]
# ### Factual Recall
#
# Let’s set up the model and test it on the fact we want to causal trace: “A cat sat on the mat and he”.

# %%
def get_probs(out):
    last_logits = out.logits[0, -1]            # (vocab_size,)
    dist = F.softmax(last_logits, dim=-1)

    topk      = torch.topk(dist, k=10)
    top_ids   = topk.indices.tolist()
    top_probs = topk.values.tolist()
    
    return topk, top_ids, top_probs

# %%
# Example: one-shot prompt
# one_shot = (
#     "Lily the cat relaxed on the mat and she ate an apple. → ate\n"
#     "Aki the dog barked at the mailman and he ran away. → ran\n"
#     "Coco the bird perched on the branch and it chirped a tune. → chirped\n"
#     "Lily the cat relaxed on the mat and she"
# )
one_shot = (
    "Lily the cat relaxed on the mat and she ate an apple.\n"
    "Lily the cat sits on the mat and she smells an apple.\n"
    "Lily the cat relaxed on the mat and she"
)
inputs = tokenizer(one_shot, return_tensors="pt").to(device)

with torch.no_grad():
    out = model(**inputs)
    
topk, top_ids, top_probs = get_probs(out)

print(one_shot)
for tok_id, prob in zip(top_ids, top_probs):
    token = tokenizer.decode([tok_id]).strip()
    print(f"{token}\t{prob:.4f}")
# Out:
# Lily the cat relaxed on the mat and she ate an apple.
# Lily the cat sits on the mat and she smells an apple.
# Lily the cat relaxed on the mat and she
# ate	0.5029
# smelled	0.0945
# smells	0.0475
# eats	0.0364
# licked	0.0191
# sniff	0.0178
# drank	0.0157
# saw	0.0127
# sm	0.0116
# looked	0.0116

# %% [markdown]
# ### Intervention

# %%
# 1) Define the noise intervention class
class NoiseIntervention(ConstantSourceIntervention, LocalistRepresentationIntervention):
    def __init__(self, embed_dim=None, **kwargs):
        super().__init__()
        # pull the provided size
        embed_dim = embed_dim or kwargs.get("latent_dim")
        if embed_dim is None:
            raise ValueError(f"No latent_dim in kwargs: {list(kwargs)}")
        self.interchange_dim = embed_dim

        rs = np.random.RandomState(1)
        prng = lambda *shape: rs.randn(*shape)
        self.noise = torch.from_numpy(prng(1, 1, embed_dim)).to(device)
#         self.noise_level = 0.13462981581687927
        self.noise_level = 0.33462981581687927

    def forward(self, base, source=None, subspaces=None):
        base[..., :self.interchange_dim] += self.noise * self.noise_level
        return base
    
# 2) Build a corrupt config for Llama-3.1 8B
def corrupted_config(model_type, layer):
    return IntervenableConfig(
        model_type=model_type,
        representations=[
            RepresentationConfig(
                layer,
                "block_input"
            ),
        ],
        intervention_types=NoiseIntervention,
    )

# %%
# 5) Create intervenable wrapper for a given layer
layer = 0

base = tokenizer(one_shot, return_tensors="pt").to(device)
config = corrupted_config(type(model), layer)
intervenable = IntervenableModel(config, model)

# %% [markdown]
# Let’s check that this reduced the probability of the output past tense verbs.

# %%
# prompt = "Lily the cat relaxed on the mat and she"
inputs = tokenizer(one_shot, return_tensors="pt")
input_ids = inputs["input_ids"][0].tolist()
tokens    = tokenizer.convert_ids_to_tokens(input_ids)

# print token indices
for idx, tok in enumerate(tokens):
    print(idx, tok)
# Out:
# 0 <|begin_of_text|>
# 1 L
# 2 ily
# 3 Ġthe
# 4 Ġcat
# 5 Ġrelaxed
# 6 Ġon
# 7 Ġthe
# 8 Ġmat
# 9 Ġand
# 10 Ġshe
# 11 Ġate
# 12 Ġan
# 13 Ġapple
# 14 .Ċ
# 15 L
# 16 ily
# 17 Ġthe
# 18 Ġcat
# 19 Ġsits
# 20 Ġon
# 21 Ġthe
# 22 Ġmat
# 23 Ġand
# 24 Ġshe
# 25 Ġsmells
# 26 Ġan
# 27 Ġapple
# 28 .Ċ
# 29 L
# 30 ily
# 31 Ġthe
# 32 Ġcat
# 33 Ġrelaxed
# 34 Ġon
# 35 Ġthe
# 36 Ġmat
# 37 Ġand
# 38 Ġshe

# %%
pos_restore = [5,11,33]

# %%
# 2) Intervention at token
unit_locations = {
    "base": [[           # one batch
      pos_restore
    ]]
}

_, counterfactual_outputs = intervenable(base, unit_locations=unit_locations)

# 3) Extract logits & distributions
topk, top_ids, top_probs = get_probs(counterfactual_outputs)

# Decode and print
print(one_shot)
for tok_id, prob in zip(top_ids, top_probs):
    token = tokenizer.decode([tok_id]).strip()
    print(f"{token}\t{prob:.4f}")
# Out:
# Lily the cat relaxed on the mat and she ate an apple.
# Lily the cat sits on the mat and she smells an apple.
# Lily the cat relaxed on the mat and she
# eats	0.1187
# smells	0.1089
# sees	0.0703
# likes	0.0583
# reads	0.0307
# hears	0.0286
# has	0.0271
# ate	0.0255
# ’s	0.0216
# 's	0.0198

# %% [markdown]
# ### Restored run
#
# We now make a config that performs the following:
#
# - Corrupt input embeddings for some positions.
#
# - Restore the hidden state at a particular layer for some (potentially different positions).
#
# This is how Meng et al. check where in the model the fact moves through.

# %%
def restore_corrupted_with_interval_config(
    intervened_layer: int,
    restore_layer: int,
    stream: str = "mlp",
    window: int = 2,
    num_layers: int = 33,
):
    # compute restore interval around restore_layer
    half = window // 2
    start = max(0, restore_layer - half)
    end   = min(num_layers, restore_layer + half + 1)
    
    reps = []
    types = []
    
    # First: corrupt the embedding of token position later
    reps.append(
      RepresentationConfig(
        0,
        "block_input"
      )
    )
    types.append(NoiseIntervention)
    
    # Then: restore hidden state at each layer in [start, end)
    for L in range(start, end):
        reps.append(
          RepresentationConfig(
            L,
            stream 
          )
        )
        types.append(VanillaIntervention)
    
    return IntervenableConfig(
      model_type=type(model),
      representations=reps,
      intervention_types=types
    )

# %% [markdown]
# Now let’s run this over all layers and positions! We will corrupt position 3 (“sat”, i.e. the past tense verb) and restore at a single position at every layer.

# %%
token_id = tokenizer.encode(" ate", add_special_tokens=False)[0]
base = tokenizer(one_shot, return_tensors="pt").to(device)

token_id
# Out:
# 30912

# %% [markdown]
# llama_type_to_module_mapping:
# https://github.com/stanfordnlp/pyvene/blob/main/pyvene/models/llama/modelings_intervenable_llama.py

# %%
for stream in ["block_output", "mlp_activation", "attention_output", "mlp_output"]:
    records = []
    for restore_layer in range(model.config.num_hidden_layers):
        for pos in range(inputs.input_ids.size(1)):
            cfg = restore_corrupted_with_interval_config(
                intervened_layer=0,      # we only corrupt at input
                restore_layer=restore_layer,
                stream=stream,
                window=2,
                num_layers=model.config.num_hidden_layers
            )
            interv = IntervenableModel(cfg, model)
            
            # sources→targets mapping: corrupt at embed_tokens output, restore at each hidden stream
            n_restores = len(cfg.representations) - 1
            _, cf_out = interv(
                base,
                [None] + [base]*n_restores,
                {
                    "sources->base": (
                        [None] + [[[pos]]]*n_restores,
                        [[pos_restore]] + [[[pos]]]*n_restores,
                    )
                },
            )
            
            dist = cf_out.logits.softmax(-1)
            prob = dist[0, -1, token_id].item()
            
            # Extract the top‐1 predicted token and its probability
            top_val, top_idx = torch.topk(dist[0, -1], k=1)
            top_id   = top_idx.item()
            top_prob = top_val.item()
            top_tok  = tokenizer.decode([top_id]).strip()
            
            records.append({
                "restore_layer": restore_layer,
                "pos": pos,
                "stream": stream,
                "prob": prob,
                "top_token": top_tok,
                "top_prob": top_prob,
            })
    
    pd.DataFrame(records).to_csv(f"pyvene_past_{stream}.csv", index=False)

# %% [markdown]
# Caption: The heatmaps show the probability of the correct past‐tense verb “ate” when restoring corrupted hidden states at each layer (x-axis) and token position (y-axis) across four internal data streams of Llama-3.1-8B: Block Output, MLP Activation, Attention Output, and MLP Output. Darker cells indicate higher recovery of the original “ate” prediction. In each heatmap, (“*”) denotes the noise injected token positions.
#
# Interpretation:
# Importance of tokens & layers: There is the most prominent causal influence for correct tense verb prediction, when we restore the original hidden states at past-tense verb tokens that we intervened. Because we see darker cells in earlier layers (0-15), when we restore these tokens to its original in these earlier layers, there are the most causal effect for final token prediction "ate". Moreover, we also see that non-verb token "she" which occurs before "ate" has its influence in the later layers (16-31). Perhaps, it means that token "she" contains its subsequent token information (in our case, past-tense), but not the token "she" in the early-middle layers but the token "she" in the later layers.
# Importance of input streams: Block output results show a broader band spanning several adjacent layers which implies syntax signals emerge gradually in the residual stream. When we perform MLP Activation restoration, we see only narrow peak at middle layers (13-16) for token "ate" and "relaxed", and for "she" at final few layers (30-32). Meanwhile, in MLP output, we stopped seeing effects in past-tense verbs, but the influence of subsequent token "she" remains in later layers (28-30). This suggest that, whether the nonlinear activation or the output projection holds the signal in token "she". In attention output, there is no causal effect for verb tokens but the token "she". In middle layers (16-17), we see some darker cells indicating some attention heads may be responsible for tense causal effect stored in its subsequent token. We report further figures for detailed analysis in Figure ...

# %%
# Shared settings
streams = ["block_output", "mlp_activation", "attention_output", "mlp_output"]

custom_labels = ["[BOS]", "L", "ily", "the", "cat", "relaxed*", "on", "the", "mat", "and", "she", "ate*", "an", "apple", ".",
                "L", "ily", "the", "cat", "sits", "on", "the", "mat", "and", "she", "smells", "an", "apple", ".",
                "L", "ily", "the", "cat", "relaxed*", "on", "the", "mat", "and", "she"]
breaks = list(range(len(custom_labels)))
cmaps = {
    "block_output": "YlGnBu",
    "mlp_activation": "PuRd",
    "attention_output": "BuPu",
    "mlp_output": "YlOrBr"
}
titles = {
    "block_output": "Block Output",
    "mlp_activation": "MLP Activation",
    "attention_output": "Attention Output",
    "mlp_output": "MLP Output"
}

for stream in streams:
    # Load and prepare
    df = pd.read_csv(f"pyvene_past_{stream}.csv")
    df["layer"] = df["restore_layer"].astype(int)  # or "layer" if named so
    df["pos"]   = df["pos"].astype(int)
    df["p_was"] = df["prob"].astype(float)

    # Pivot: rows=pos, cols=layer
    pivot = df.pivot(index="pos", columns="layer", values="p_was")

    # Plot heatmap
    plt.figure(figsize=(8, 8))
    ax = sns.heatmap(
        pivot,
        cmap=cmaps[stream],
        vmin=0, 
        cbar_kws={"label": "P('ate')"}
    )
    ax.set_title(f"Probability of 'ate' · Restore at {titles[stream]}")
    ax.set_xlabel("Restored Layer")
    ax.set_ylabel("Restored Token Position")
    ax.set_yticks(breaks)
    ax.set_yticklabels(custom_labels, rotation=0)

    plt.tight_layout()
    plt.show()

# %%
for stream in streams:
    # Load and prepare
    df = pd.read_csv(f"pyvene_past_{stream}.csv")
    df_stream = df[df["stream"] == stream]
    pivot_prob  = df_stream.pivot(index="pos", columns="restore_layer", values="top_prob")
    pivot_token = df_stream.pivot(index="pos", columns="restore_layer", values="top_token")

    # align token‐pivot to prob‐pivot shape
    pivot_token = pivot_token.reindex(
        index = pivot_prob.index,
        columns = pivot_prob.columns
    )

    plt.figure(figsize=(18, 10))
    ax = sns.heatmap(pivot_prob, cmap=cmaps[stream], cbar_kws={"label": "Top‐Predicted Verb Probability"})
    for i, pos in enumerate(pivot_prob.index):
        for j, layer in enumerate(pivot_prob.columns):
            token_str = pivot_token.loc[pos, layer]
            prob_val  = pivot_prob.loc[pos, layer]
            if pd.notna(token_str):
                ax.text(
                    j + 0.5, i + 0.5, token_str,
                    ha="center", va="center",
                    fontsize=6,
                    color="black" if prob_val < 0.5 else "white"
                )
    ax.set_xlabel("Restored Layer")
    ax.set_ylabel("Restored Token Position")
    ax.set_yticks(range(len(custom_labels)))
    ax.set_yticklabels(custom_labels, rotation=0)
    plt.title(f"Stream = {stream}: Top‐Predicted Token (w/ Prob.)")
    plt.tight_layout()
    plt.show()

# %%
for stream in ["block_output", "mlp_activation", "attention_output", "mlp_output"]:
    records = []
    for restore_layer in range(model.config.num_hidden_layers):
        # Build a single config that corrupts at layer 0 and restores at window around restore_layer
        cfg = restore_corrupted_with_interval_config(
            intervened_layer=0,
            restore_layer=restore_layer,
            stream=stream,
            window=1,
            num_layers=model.config.num_hidden_layers
        )
        interv = IntervenableModel(cfg, model)

        # Number of restore steps = total reps − 1 corruption
        n_restores = len(cfg.representations) - 1

        # Prepare the list of source/target position lists for all restores
        # First entry None for corruption; then the same pos_restore for each restoration
        sources = [None] + [base] * n_restores
        source_positions = [None] + [[pos_restore]] * n_restores
        target_positions = [[pos_restore]] + [[pos_restore]] * n_restores

        # Run the intervened forward pass once per restore_layer
        _, cf_out = interv(
            base,
            sources,
            {"sources->base": (source_positions, target_positions)}
        )

        # Compute distribution and metrics
        dist = cf_out.logits.softmax(dim=-1)
        prob_correct = dist[0, -1, token_id].item()
        top_val, top_idx = torch.topk(dist[0, -1], k=1)
        top_tok  = tokenizer.decode([top_idx.item()]).strip()
        top_prob = top_val.item()

        records.append({
            "restore_layer": restore_layer,
            "stream": stream,
            "prob_correct": prob_correct,
            "top_token": top_tok,
            "top_prob": top_prob,
        })

    pd.DataFrame(records).to_csv(f"pyvene_past_all_{stream}.csv", index=False)

# %%
# 1) Load and concatenate
dfs = []
for stream in ["block_output","mlp_activation","attention_output","mlp_output"]:
    tmp = pd.read_csv(f"pyvene_past_all_{stream}.csv")
    tmp["stream"]      = stream
    tmp["layer"]       = tmp["restore_layer"].astype(int)
    tmp["prob_correct"] = tmp["prob_correct"].astype(float)
    tmp["top_prob"]    = tmp["top_prob"].astype(float)
    tmp["top_token"]   = tmp["top_token"].astype(str)
    tmp["top_display"] = tmp["top_token"] + " (" + tmp["top_prob"].round(3).astype(str) + ")"
    # combine into one display string
    dfs.append(tmp[["layer","stream","prob_correct","top_display","top_token","top_prob"]])
df_all = pd.concat(dfs, ignore_index=True)

# 2) Pivot so streams become columns, layers rows
pivot = df_all.pivot(index="layer", columns="stream", values="top_display")

# 3) Show
print(pivot.to_string())
# Out:
# stream attention_output    block_output  mlp_activation      mlp_output
# layer
# 0           eats (0.12)     ate (0.512)     eats (0.12)    eats (0.127)
# 1          eats (0.124)      ate (0.53)    eats (0.119)    eats (0.129)
# 2           eats (0.11)     ate (0.633)    eats (0.126)    eats (0.141)
# 3        smells (0.133)     ate (0.582)    eats (0.121)    eats (0.134)
# 4        smells (0.127)     ate (0.587)    eats (0.121)    eats (0.116)
# 5        smells (0.122)     ate (0.603)    eats (0.123)    eats (0.126)
# 6        smells (0.126)     ate (0.595)    eats (0.115)   smells (0.12)
# 7         smells (0.12)     ate (0.636)  smells (0.125)  smells (0.144)
# 8          eats (0.125)     ate (0.624)  smells (0.131)  smells (0.134)
# 9          eats (0.123)     ate (0.575)  smells (0.118)  smells (0.121)
# 10        smells (0.12)     ate (0.572)  smells (0.139)  smells (0.131)
# 11       smells (0.128)      ate (0.58)    eats (0.117)  smells (0.132)
# 12         eats (0.122)     ate (0.549)    eats (0.133)  smells (0.139)
# 13          eats (0.12)     ate (0.527)    eats (0.133)  smells (0.129)
# 14         eats (0.121)      ate (0.49)  smells (0.111)  smells (0.118)
# 15          eats (0.12)     ate (0.305)  smells (0.105)  smells (0.145)
# 16         eats (0.128)     ate (0.212)  smells (0.118)  smells (0.147)
# 17         eats (0.122)  smells (0.276)  smells (0.155)  smells (0.174)
# 18         eats (0.118)  smells (0.263)  smells (0.118)  smells (0.153)
# 19         eats (0.119)  smells (0.221)    eats (0.125)  smells (0.131)
# 20          eats (0.13)   smells (0.18)    eats (0.114)    eats (0.113)
# 21         eats (0.123)  smells (0.181)    eats (0.123)  smells (0.115)
# 22          eats (0.12)    eats (0.175)    eats (0.126)     eats (0.13)
# 23         eats (0.121)    eats (0.166)     eats (0.13)     eats (0.12)
# 24         eats (0.119)    eats (0.166)    eats (0.117)    eats (0.119)
# 25         eats (0.121)    eats (0.161)    eats (0.121)    eats (0.118)
# 26         eats (0.115)    eats (0.173)    eats (0.122)    eats (0.118)
# 27         eats (0.119)    eats (0.161)    eats (0.122)    eats (0.125)
# 28          eats (0.12)    eats (0.163)    eats (0.122)    eats (0.125)
# 29         eats (0.118)    eats (0.163)    eats (0.123)    eats (0.125)
# 30         eats (0.119)     eats (0.12)    eats (0.119)    eats (0.119)
# 31         eats (0.119)    eats (0.119)    eats (0.119)    eats (0.119)

# %%
plt.figure(figsize=(10,6))
for stream, group in df_all.groupby("stream"):
    plt.plot(
        group["layer"],
        group["prob_correct"],
        marker="o",
        label=stream
    )

plt.title("Recovery of P('ate') by Restored Layer and Stream")
plt.xlabel("Restored Layer")
plt.ylabel("P(correct='ate')")
plt.legend(title="Stream")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
pivot_prob  = df_all.pivot(index="stream", columns="layer", values="top_prob")
pivot_token = df_all.pivot(index="stream", columns="layer", values="top_token")

# 2. Plot
plt.figure(figsize=(16, 2))
ax = sns.heatmap(
    pivot_prob, 
    annot=False, 
    fmt=".2f", 
    cmap="YlOrBr", 
    cbar_kws={"label": "Top Token Probability"}
)

# 3. Add top_token labels
for i, stream in enumerate(pivot_prob.index):
    for j, layer in enumerate(pivot_prob.columns):
        token = pivot_token.loc[stream, layer]
        prob  = pivot_prob.loc[stream, layer]
        if pd.notna(token):
            ax.text(
                j + 0.5, i + 0.5, token,
                ha="center", va="center",
                fontsize=6,
                color="black" if prob < 0.5 else "white"
            )

# 4. Aesthetics
ax.set_xlabel("Restored Layer")
ax.set_ylabel("Stream")
ax.set_title("Top-Predicted Token and Probability by Layer and Stream")
plt.tight_layout()
plt.show()
